# %% [markdown]
# # ณธกฤต ลลิตพุฒิโชค 6110405990 Practice Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1

# %%
medals = pd.read_csv('Downloads/olympics_cleaned.csv')

# %% [markdown]
# # 2

# %%
medals
# Out:
#                               Country Code  SummerGame  SummerGold  \
# 0                         Afghanistan  AFG          13           0
# 1                             Algeria  ALG          12           5
# 2                           Argentina  ARG          23          18
# 3                             Armenia  ARM           5           1
# 4                         Australasia  ANZ           2           3
# ..                                ...  ...         ...         ...
# 141                        Yugoslavia  YUG          16          26
# 142  Independent Olympic Participants  IOP           1           0
# 143                            Zambia  ZAM          12           0
# 144                          Zimbabwe  ZIM          12           3
# 145                        Mixed team  ZZX           3           8
#
#      SummerSilver  SummerBronze  WinterGame  WinterGold  WinterSilver  \
# 0               0             2           0           0             0
# ...

# %%
medals.shape
# Out:
# (146, 10)

# %% [markdown]
# # 3

# %%
medals['Code'].is_unique
# Out:
# True

# %% [markdown]
# # 4

# %%
medals = medals.set_index('Code')

# %%
medals
# Out:
#                                Country  SummerGame  SummerGold  SummerSilver  \
# Code
# AFG                        Afghanistan          13           0             0
# ALG                            Algeria          12           5             2
# ARG                          Argentina          23          18            24
# ARM                            Armenia           5           1             2
# ANZ                        Australasia           2           3             4
# ...                                ...         ...         ...           ...
# YUG                         Yugoslavia          16          26            29
# IOP   Independent Olympic Participants           1           0             1
# ZAM                             Zambia          12           0             1
# ZIM                           Zimbabwe          12           3             4
# ZZX                         Mixed team           3           8             5
#
# ...

# %% [markdown]
# # 5

# %%
medals['SummerGold']
# Out:
# Code
# AFG     0
# ALG     5
# ARG    18
# ARM     1
# ANZ     3
#        ..
# YUG    26
# IOP     0
# ZAM     0
# ZIM     3
# ZZX     8
# Name: SummerGold, Length: 146, dtype: int64

# %% [markdown]
# # 6

# %%
medals.loc['USA' , :]
# Out:
# Country         United States
# SummerGame                 26
# SummerGold                976
# SummerSilver              757
# SummerBronze              666
# WinterGame                 22
# WinterGold                 96
# WinterSilver              102
# WinterBronze               84
# Name: USA, dtype: object

# %%
medals.loc[medals.Country == 'United States']
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# USA           22          96           102            84

# %% [markdown]
# # 7

# %%
medals.loc[: , 'SummerGame': 'SummerBronze']
# Out:
#       SummerGame  SummerGold  SummerSilver  SummerBronze
# Code
# AFG           13           0             0             2
# ALG           12           5             2             8
# ARG           23          18            24            28
# ARM            5           1             2             9
# ANZ            2           3             4             5
# ...          ...         ...           ...           ...
# YUG           16          26            29            28
# IOP            1           0             1             2
# ZAM           12           0             1             1
# ZIM           12           3             4             1
# ZZX            3           8             5             4
#
# [146 rows x 4 columns]

# %% [markdown]
# # 8

# %%
medals.loc[['THA' , 'SIN' , 'MAS']  , ['SummerGold' , 'WinterGold']]
# Out:
#       SummerGold  WinterGold
# Code
# THA            7           0
# SIN            0           0
# MAS            0           0

# %% [markdown]
# # 9
# แสดงข้อมูลเหรียญเงินและเหรียญทองแดงของโอลิมปิคฤดูร้อนของประเทศฝรั่งเศส (FRA) และสเปน (ESP)แสดงชื่อประเทศด้วย

# %%
medals.loc[['FRA' , 'ESP'] , ['Country' , 'SummerSilver' , 'SummerBronze']]
# Out:
#      Country  SummerSilver  SummerBronze
# Code
# FRA   France           223           246
# ESP    Spain            59            35

# %% [markdown]
# # 10

# %%
medals.loc[medals.SummerGame  > 24 ].sort_values('SummerGame' , ascending = False)
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# GRE          Greece          27          30            42            39
# SUI     Switzerland          27          47            73            65
# AUT         Austria          26          18            33            35
# DEN         Denmark          26          43            68            68
# ITA           Italy          26         198           166           185
# SWE          Sweden          26         143           164           176
# USA   United States          26         976           757           666
# AUS       Australia          25         139           152           177
# BEL         Belgium          25          37            52            53
# CAN          Canada          25          59            99           121
# ...

# %% [markdown]
# # 11

# %%
medals.loc[medals.SummerGold > 200].sort_values('SummerGold' , ascending = False)
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# USA   United States          26         976           757           666
# URS    Soviet Union           9         395           319           296
# GBR   Great Britain          27         236           272           272
# FRA          France          27         202           223           246
# CHN           China           9         201           146           126
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# USA           22          96           102            84
# URS            9          78            57            59
# GBR           22          10             4            12
# FRA           22          31            31            47
# CHN           10          12            22            19

# %% [markdown]
# # 12

# %%
medals.loc[(medals.SummerGold > 200) & (medals.SummerSilver > 200),'Country':'SummerSilver']
# Out:
#             Country  SummerGame  SummerGold  SummerSilver
# Code
# FRA          France          27         202           223
# GBR   Great Britain          27         236           272
# URS    Soviet Union           9         395           319
# USA   United States          26         976           757

# %% [markdown]
# # 13

# %%
medals.loc[medals.WinterGold > medals.WinterSilver , ['Country','WinterGold','WinterSilver']]
# Out:
#                      Country  WinterGold  WinterSilver
# Code
# AUS                Australia           5             3
# BLR                  Belarus           6             4
# CAN                   Canada          62            56
# EST                  Estonia           4             2
# EUA   United Team of Germany           8             6
# GDR             East Germany          39            36
# GBR            Great Britain          10             4
# ITA                    Italy          37            34
# KOR              South Korea          26            17
# NOR                   Norway         118           111
# RUS                   Russia          49            40
# URS             Soviet Union          78            57
# EUN             Unified Team           9             6
# ESP                    Spain           1             0
# SWE                   Sweden          50            40
# SUI              Switzerland          50            40
# ...

# %% [markdown]
# # 14

# %%
medals.loc[medals.WinterGold > (medals.WinterSilver + medals.WinterBronze),['Country','WinterGold','WinterSilver','WinterBronze']]
# Out:
#          Country  WinterGold  WinterSilver  WinterBronze
# Code
# EST      Estonia           4             2             1
# UZB   Uzbekistan           1             0             0

# %% [markdown]
# # 15

# %%
medals.loc[medals.Country.str.startswith('A')]
# Out:
#           Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# AFG   Afghanistan          13           0             0             2
# ALG       Algeria          12           5             2             8
# ARG     Argentina          23          18            24            28
# ARM       Armenia           5           1             2             9
# ANZ   Australasia           2           3             4             5
# AUS     Australia          25         139           152           177
# AUT       Austria          26          18            33            35
# AZE    Azerbaijan           5           6             5            15
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# AFG            0           0             0             0
# ALG            3           0             0             0
# ARG           18           0             0             0
# ARM            6           0             0             0
# ...

# %% [markdown]
# # 16

# %%
max_col = medals['SummerGame']

# %%
maxSummerGame = max_col.max()

# %%
maxSummerGame
# Out:
# 27

# %% [markdown]
# # 17

# %%
medals.loc[medals.SummerGame == maxSummerGame]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# GRE          Greece          27          30            42            39
# SUI     Switzerland          27          47            73            65
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# FRA           22          31            31            47
# GBR           22          10             4            12
# GRE           18           0             0             0
# SUI           22          50            40            48

# %% [markdown]
# # 18

# %%
max_col_winter = medals['WinterGame']

# %%
maxWinterGame = max_col_winter.max()

# %%
maxWinterGame
# Out:
# 22

# %%
len(medals.loc[medals.WinterGame == maxWinterGame])
# Out:
# 12

# %% [markdown]
# # 19

# %%
total_WinterGold= medals['WinterGold'].sum()

# %%
total_WinterSilver = medals['WinterSilver'].sum()

# %%
total_WinterBronze = medals['WinterBronze'].sum()

# %%
total_Winter = total_WinterGold + total_WinterSilver + total_WinterBronze

# %%
total_Winter
# Out:
# 2865

# %% [markdown]
# # 20

# %%
medals.loc[: , ['WinterGold','SummerGold']].mean(axis=1)
# Out:
# Code
# AFG     0.0
# ALG     2.5
# ARG     9.0
# ARM     0.5
# ANZ     1.5
#        ...
# YUG    13.0
# IOP     0.0
# ZAM     0.0
# ZIM     1.5
# ZZX     4.0
# Length: 146, dtype: float64

# %% [markdown]
# # 21

# %%
medals.drop(['SummerGame','WinterGame',],axis='columns').sum(axis = 1)
# Out:
# Code
# AFG     2
# ALG    15
# ARG    70
# ARM    12
# ANZ    12
#        ..
# YUG    87
# IOP     3
# ZAM     2
# ZIM     8
# ZZX    17
# Length: 146, dtype: int64

# %% [markdown]
# # 22

# %%
medalsdrop  = medals.drop(['SummerGame','WinterGame',],axis='columns')
medalsdrop
# Out:
#                                Country  SummerGold  SummerSilver  \
# Code
# AFG                        Afghanistan           0             0
# ALG                            Algeria           5             2
# ARG                          Argentina          18            24
# ARM                            Armenia           1             2
# ANZ                        Australasia           3             4
# ...                                ...         ...           ...
# YUG                         Yugoslavia          26            29
# IOP   Independent Olympic Participants           0             1
# ZAM                             Zambia           0             1
# ZIM                           Zimbabwe           3             4
# ZZX                         Mixed team           8             5
#
#       SummerBronze  WinterGold  WinterSilver  WinterBronze
# Code
# AFG              2           0             0             0
# ...

# %%
medalsdrop['allWinter']  = medalsdrop.loc[: , 'WinterGold' : 'WinterBronze' ].sum(axis = 1)

# %%
medalsdrop['allSummer'] = medalsdrop.loc[: , 'SummerGold' : 'SummerBronze' ].sum(axis = 1)

# %%
medalsdrop.loc[medalsdrop.allWinter > medalsdrop.allSummer , ['Country' ,'allWinter' ,'allSummer']]
# Out:
#             Country  allWinter  allSummer
# Code
# AUT         Austria        218         86
# LIE   Liechtenstein          9          0
# NOR          Norway        329        148

# %% [markdown]
# # 23

# %%
medalsdrop.loc[medalsdrop.allWinter == 0 , ['allWinter','allSummer']]
# Out:
#       allWinter  allSummer
# Code
# AFG           0          2
# ALG           0         15
# ARG           0         70
# ARM           0         12
# ANZ           0         12
# ...         ...        ...
# ISV           0          1
# IOP           0          3
# ZAM           0          2
# ZIM           0          8
# ZZX           0         17
#
# [101 rows x 2 columns]

# %%
medalsdrop.loc[medalsdrop.allSummer == 0 , ['allWinter','allSummer']]
# Out:
#       allWinter  allSummer
# Code
# LIE           9          0

# %%
medalsdrop.loc[(medalsdrop.allWinter == 0) | (medalsdrop.allSummer == 0) , ['Country','allWinter','allSummer']]
# Out:
#                                Country  allWinter  allSummer
# Code
# AFG                        Afghanistan          0          2
# ALG                            Algeria          0         15
# ARG                          Argentina          0         70
# ARM                            Armenia          0         12
# ANZ                        Australasia          0         12
# ...                                ...        ...        ...
# ISV                     Virgin Islands          0          1
# IOP   Independent Olympic Participants          0          3
# ZAM                             Zambia          0          2
# ZIM                           Zimbabwe          0          8
# ZZX                         Mixed team          0         17
#
# [102 rows x 3 columns]

# %% [markdown]
# # 24

# %%
medals.sort_values('SummerGold').loc[:,['Country','SummerGold']]
# Out:
#             Country  SummerGold
# Code
# AFG     Afghanistan           0
# NAM         Namibia           0
# MNE      Montenegro           0
# MDA         Moldova           0
# MRI       Mauritius           0
# ...             ...         ...
# CHN           China         201
# FRA          France         202
# GBR   Great Britain         236
# URS    Soviet Union         395
# USA   United States         976
#
# [146 rows x 2 columns]

# %% [markdown]
# # 25

# %%
medals.sort_values(['SummerGold','SummerGame'] , ascending = [False,True]).loc[: , ['Country' , 'SummerGame','SummerGold']]
# Out:
#             Country  SummerGame  SummerGold
# Code
# USA   United States          26         976
# URS    Soviet Union           9         395
# GBR   Great Britain          27         236
# FRA          France          27         202
# CHN           China           9         201
# ...             ...         ...         ...
# SRI       Sri Lanka          16           0
# BER         Bermuda          17           0
# PUR     Puerto Rico          17           0
# ISL         Iceland          19           0
# PHI     Philippines          20           0
#
# [146 rows x 3 columns]

# %% [markdown]
# # 26

# %%
medals['score'] = medals['SummerGold']*3 + medals['SummerSilver']*2 + medals['SummerBronze'] + medals['WinterGold']*3 + medals['WinterSilver']*2 + medals['WinterBronze']

# %%
medals
# Out:
#                                Country  SummerGame  SummerGold  SummerSilver  \
# Code
# AFG                        Afghanistan          13           0             0
# ALG                            Algeria          12           5             2
# ARG                          Argentina          23          18            24
# ARM                            Armenia           5           1             2
# ANZ                        Australasia           2           3             4
# ...                                ...         ...         ...           ...
# YUG                         Yugoslavia          16          26            29
# IOP   Independent Olympic Participants           1           0             1
# ZAM                             Zambia          12           0             1
# ZIM                           Zimbabwe          12           3             4
# ZZX                         Mixed team           3           8             5
#
# ...

# %%
medals.sort_values('score' ,  ascending = False).loc[:,['Country' , 'score']][0:10]
# Out:
#             Country  score
# Code
# USA   United States   5684
# URS    Soviet Union   2526
# GBR   Great Britain   1574
# GER         Germany   1546
# FRA          France   1500
# ITA           Italy   1333
# SWE          Sweden   1217
# CHN           China   1120
# GDR    East Germany   1068
# RUS          Russia   1042

# %% [markdown]
# # 27

# %%
scoreSummer  = (medals['SummerGold']*3 + medals['SummerSilver']*2 + medals['SummerBronze']) / medals['SummerGame']

# %%
scoreSummer
# Out:
# Code
# AFG     0.153846
# ALG     2.250000
# ARG     5.652174
# ARM     3.200000
# ANZ    11.000000
#          ...
# YUG    10.250000
# IOP     4.000000
# ZAM     0.250000
# ZIM     1.500000
# ZZX    12.666667
# Length: 146, dtype: float64

# %%
scoreWinter = (medals['WinterGold']*3 + medals['WinterSilver']*2 + medals['WinterBronze']) / medals['WinterGame']

# %%
scoreWinter = scoreWinter.fillna(0)

# %%
medals['perGame'] = scoreSummer + scoreWinter

# %%
medals
# Out:
#                                Country  SummerGame  SummerGold  SummerSilver  \
# Code
# AFG                        Afghanistan          13           0             0
# ALG                            Algeria          12           5             2
# ARG                          Argentina          23          18            24
# ARM                            Armenia           5           1             2
# ANZ                        Australasia           2           3             4
# ...                                ...         ...         ...           ...
# YUG                         Yugoslavia          16          26            29
# IOP   Independent Olympic Participants           1           0             1
# ZAM                             Zambia          12           0             1
# ZIM                           Zimbabwe          12           3             4
# ZZX                         Mixed team           3           8             5
#
# ...

# %%
medals.sort_values('perGame')[0:10]
# Out:
#           Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# BER       Bermuda          17           0             0             1
# GUY        Guyana          16           0             0             1
# IRQ          Iraq          13           0             0             1
# NIG         Niger          11           0             0             1
# BAR      Barbados          11           0             0             1
# TOG          Togo           9           0             0             1
# MRI     Mauritius           8           0             0             1
# BRN       Bahrain           8           0             0             1
# DJI      Djibouti           7           0             0             1
# AFG   Afghanistan          13           0             0             2
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze  score   perGame
# Code
# BER            7           0             0             0      1  0.058824
# ...
