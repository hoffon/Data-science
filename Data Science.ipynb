# %% [markdown]
# # ณธกฤต ลลิพุฒิโชค 6110405990

# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1

# %%
df = pd.read_csv("hotel_bookings.csv")
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# # 2

# %%
df.loc[[9,10,11,12,13,14]]
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 9   Resort Hotel            1         75               2015
# 10  Resort Hotel            1         23               2015
# 11  Resort Hotel            0         35               2015
# 12  Resort Hotel            0         68               2015
# 13  Resort Hotel            0         18               2015
# 14  Resort Hotel            0         37               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 9                July                        27                          1
# 10               July                        27                          1
# 11               July                        27                          1
# 12               July                        27                          1
# 13               July                        27                          1
# 14               July                        27                          1
#
# ...

# %% [markdown]
# # 3

# %%
df.loc[:,('arrival_date_year','arrival_date_month', 'arrival_date_day_of_month')].head(5)
# Out:
#    arrival_date_year arrival_date_month  arrival_date_day_of_month
# 0               2015               July                          1
# 1               2015               July                          1
# 2               2015               July                          1
# 3               2015               July                          1
# 4               2015               July                          1

# %% [markdown]
# # 4

# %%
df['arrival_date'] = df['arrival_date_day_of_month'].map(str) + '-' + df['arrival_date_month'].map(str) + '-' + df['arrival_date_year'].map(str)

# %%
df['arrival_date']
# Out:
# 0            1-July-2015
# 1            1-July-2015
# 2            1-July-2015
# 3            1-July-2015
# 4            1-July-2015
#                ...
# 119385    30-August-2017
# 119386    31-August-2017
# 119387    31-August-2017
# 119388    31-August-2017
# 119389    29-August-2017
# Name: arrival_date, Length: 119390, dtype: object

# %% [markdown]
# # 5

# %%
df.drop('arrival_date_week_number',axis = 1).head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# 1                          1                        0                     0
# 2                          1                        0                     1
# 3                          1                        0                     1
# 4                          1                        0                     2
#
# ...

# %% [markdown]
# # 6

# %%
len(df.loc[df.lead_time > 365])
# Out:
# 3148

# %% [markdown]
# # 7

# %%
len(df.loc[(df.stays_in_week_nights > 0) & (df.stays_in_weekend_nights > 0)])
# Out:
# 60462

# %% [markdown]
# # 8

# %%
df.loc[df.children == 0]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# # 9

# %%
len(df.loc[(df.country == 'THA') | (df.country == 'PHL') | (df.country == 'MMR') | (df.country == 'KHM')
      | (df.country == 'VNM') | (df.country == 'IDN') | (df.country == 'LAO')])
# Out:
# 147

# %% [markdown]
# # 10

# %%
iso = pd.read_csv('ISO3166.csv')

# %%
iso['code'] = iso['Alpha-3 code']

# %%
df.country[~df.country.isin(iso.code)].unique()
# Out:
# array([nan, 'CN', 'TMP'], dtype=object)

# %% [markdown]
# # 11

# %%
df = df.merge(iso[['code','Country']],how='left',left_on='country',right_on='code')

# %%
df = df.replace(np.nan, '', regex=True)

# %%
df.tail(5)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# # 12

# %%
len(df.loc[df.Country.str.endswith('land'),'Country'].unique())
# Out:
# 7

# %% [markdown]
# # 13

# %%
sns.catplot(data=df, x='customer_type', y='lead_time', kind='box')

# %% [markdown]
# # 14

# %%
df.groupby('customer_type').mean('lead_time')
# Out:
#                  is_canceled   lead_time  arrival_date_year  \
# customer_type
# Contract            0.309617  142.969823        2015.510304
# Group               0.102253   55.057192        2016.045061
# Transient           0.407463   93.295515        2016.249517
# Transient-Party     0.254299  137.037056        2015.932375
#
#                  arrival_date_week_number  arrival_date_day_of_month  \
# customer_type
# Contract                        33.702159                  15.236261
# Group                           29.433276                  15.603120
# Transient                       26.541350                  15.795164
# Transient-Party                 28.277623                  15.904872
#
#                  stays_in_weekend_nights  stays_in_week_nights    adults  \
# customer_type
# Contract                        1.469578              3.851079  1.919529
# Group                           0.824957              2.057192  2.346620
# ...

# %% [markdown]
# # 15

# %%
df['month'] = df['reservation_status_date'].str[:7]

# %%
x = df.loc[df.is_canceled == 0]

# %%
x = x.groupby('month').count()

# %%
x.loc[:,'is_canceled']
# Out:
# month
# 2015-07    1321
# 2015-08    2224
# 2015-09    2986
# 2015-10    3304
# 2015-11    1987
# 2015-12    1640
# 2016-01    1985
# 2016-02    2435
# 2016-03    3194
# 2016-04    3347
# 2016-05    3593
# 2016-06    3168
# 2016-07    3080
# 2016-08    3240
# 2016-09    3348
# 2016-10    3694
# 2016-11    3052
# 2016-12    2233
# 2017-01    2635
# 2017-02    2705
# 2017-03    3216
# 2017-04    3182
# 2017-05    3573
# 2017-06    3198
# 2017-07    3336
# 2017-08    3097
# 2017-09     393
# Name: is_canceled, dtype: int64

# %% [markdown]
# # 16

# %%
plot = df.loc[df.is_canceled == 0]

# %%
plot = plot.groupby(['hotel','month']).count()
plot = plot.reset_index()
plot
# Out:
#            hotel    month  is_canceled  lead_time  arrival_date_year  \
# 0     City Hotel  2015-07          441        441                441
# 1     City Hotel  2015-08         1167       1167               1167
# 2     City Hotel  2015-09         1972       1972               1972
# 3     City Hotel  2015-10         2079       2079               2079
# 4     City Hotel  2015-11         1004       1004               1004
# 5     City Hotel  2015-12          802        802                802
# 6     City Hotel  2016-01         1079       1079               1079
# 7     City Hotel  2016-02         1371       1371               1371
# 8     City Hotel  2016-03         1864       1864               1864
# 9     City Hotel  2016-04         2012       2012               2012
# 10    City Hotel  2016-05         2263       2263               2263
# 11    City Hotel  2016-06         2185       2185               2185
# 12    City Hotel  2016-07         2086       2086               2086
# ...

# %%
plt.plot(plot.month,plot.is_canceled)

# %% [markdown]
# # 17

# %%
cancel =df.loc[df.is_canceled == 1]

# %%
cancel = cancel.groupby(['reserved_room_type','deposit_type']).count()

# %%
cancel.loc[:,'is_canceled']
# Out:
# reserved_room_type  deposit_type
# A                   No Deposit      19424
#                     Non Refund      14184
#                     Refundable         22
# B                   No Deposit        360
#                     Non Refund          8
# C                   No Deposit        304
#                     Non Refund          1
#                     Refundable          3
# D                   No Deposit       5879
#                     Non Refund        215
#                     Refundable          8
# E                   No Deposit       1829
#                     Non Refund         83
#                     Refundable          2
# F                   No Deposit        879
#                     Refundable          1
# G                   No Deposit        762
#                     Non Refund          1
# H                   No Deposit        243
#                     Non Refund          2
# L                   No Deposit          2
# ...
